# %%
import shap
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from catboost import CatBoostClassifier, Pool, metrics, cv
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, accuracy_score, auc
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_recall_curve
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler

from xgboost import XGBClassifier

from sklearn.linear_model import Lasso, Ridge

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
path1=Path("/Users/zainabnazari/Desktop/psp")

# %%
psp_data=pd.read_excel(path1/"genelists_102_17_7_DEGs_genes.xlsx",sheet_name='102 genes from DEGs analysis',header=None)
psp_data.dropna(how='all')
new_psp=psp_data.dropna(axis=1,how='all')

#new_psp

oo=list(new_psp.iloc[7,:])

new_psp.columns = oo

a_new_psp = new_psp.iloc[8:]

a_new_psp.reset_index(drop=True,inplace=True)

a_new_psp
# Out:
#                                               ID    Transcript_ID Gene_Symbol  \
# 0     ENST00000373606|||MANBAL|||ENSG00000101363  ENST00000373606      MANBAL
# 1     ENST00000395496|||AGPAT1|||ENSG00000204310  ENST00000395496      AGPAT1
# 2      ENST00000380265|||HERC6|||ENSG00000138642  ENST00000380265       HERC6
# 3      ENST00000636319|||PLCB1|||ENSG00000182621  ENST00000636319       PLCB1
# 4      ENST00000374176|||MAPK8|||ENSG00000107643  ENST00000374176       MAPK8
# ..                                           ...              ...         ...
# 97       ENST00000511980|||GAK|||ENSG00000178950  ENST00000511980         GAK
# 98   ENST00000362698|||RNU5A-1|||ENSG00000199568  ENST00000362698     RNU5A-1
# 99   ENST00000391141|||SNORA53|||ENSG00000212443  ENST00000391141     SNORA53
# 100    ENST00000481445|||COX7B|||ENSG00000131174  ENST00000481445       COX7B
# 101    ENST00000293842|||RPL26|||ENSG00000161970  ENST00000293842       RPL26
#
#              Gene_ID                                               Name  \
# 0    ENSG00000101363  mannosidase beta like [Source:HGNC Symbol;Acc:...
# 1    ENSG00000204310  1-acylglycerol-3-phosphate O-acyltransferase 1...
# 2    ENSG00000138642  HECT and RLD domain containing E3 ubiquitin pr...
# 3    ENSG00000182621  phospholipase C beta 1 [Source:HGNC Symbol;Acc...
# 4    ENSG00000107643  mitogen-activated protein kinase 8 [Source:HGN...
# ..               ...                                                ...
# 97   ENSG00000178950  cyclin G associated kinase [Source:HGNC Symbol...
# 98   ENSG00000199568  RNA, U5A small nuclear 1 [Source:HGNC Symbol;A...
# 99   ENSG00000212443  small nucleolar RNA, H/ACA box 53 [Source:HGNC...
# 100  ENSG00000131174  Cytochrome c oxidase subunit 7B, mitochondrial...
# 101  ENSG00000161970                              Ribosomal protein L26
#
#     Log2FC_Limma Log2FC_EdgeR Mean Log2FC
# 0      -2.066554    -1.505102   -1.785828
# 1       1.362702     1.524573    1.443637
# 2       2.273991     2.177151    2.225571
# 3      -1.328116    -1.461589   -1.394852
# 4      -2.222628    -1.345737   -1.784182
# ..           ...          ...         ...
# 97     -1.102696    -1.637117   -1.369906
# 98       -1.1364     -1.85483   -1.495615
# 99     -1.027461     -1.43763   -1.232546
# 100     1.617625     1.612341    1.614983
# 101     1.374153     1.919163    1.646658
#
# [102 rows x 8 columns]

# %%
psp_data_17=pd.read_excel(path1/"genelists_102_17_7_DEGs_genes.xlsx",sheet_name='17 genes from correlation',header=None)
psp_data_17.dropna(how='all')
new_psp_17=psp_data_17.dropna(axis=1,how='all')

a1_new_psp_17= new_psp_17.iloc[:,:8]

# %%
oo_17=list(a1_new_psp_17.iloc[1,:])
#oo_17

# %%
oo_17=list(a1_new_psp_17.iloc[1,:])

a1_new_psp_17.columns = oo_17

a_new_psp_17 = a1_new_psp_17.iloc[2:]

a_new_psp_17.reset_index(drop=True,inplace=True)

a_new_psp_17.dropna(axis=1,how='all')
# Out:
#     index                                       var1  \
# 0   16680   ENST00000297183__ANKHD1__ENSG00000131503
# 1   13715  ENST00000494302__ARHGAP4__ENSG00000089820
# 2   10893     ENST00000529713__CD3E__ENSG00000198851
# 3    8994    ENST00000325542__CEP57__ENSG00000166037
# 4    1746     ENST00000579456__CLTC__ENSG00000141367
# 5   40142   ENST00000554367__DICER1__ENSG00000100697
# 6   34685      ENST00000511980__GAK__ENSG00000178950
# 7    1464      ENST00000252951__HBZ__ENSG00000130656
# 8   22770     ENST00000329908__IST1__ENSG00000182149
# 9   55198    ENST00000650479__ITM2B__ENSG00000136156
# 10  33986  ENST00000362698__RNU5A-1__ENSG00000199568
# 11   3907   ENST00000472481__RPL13A__ENSG00000142541
# 12  11550    ENST00000647841__RPS17__ENSG00000182774
# 13  11671    ENST00000549518__SENP1__ENSG00000079387
# 14   8666    ENST00000507126__SRP72__ENSG00000174780
# 15   3740  ENST00000483001__TMEM234__ENSG00000160055
# 16  26077     ENST00000530271__WNK1__ENSG00000060237
#
#                                             NaN   Ensemble_tx_ID   Symbol  \
# 0    ENST00000297183|||ANKHD1|||ENSG00000131503  ENST00000297183   ANKHD1
# 1   ENST00000494302|||ARHGAP4|||ENSG00000089820  ENST00000494302  ARHGAP4
# 2      ENST00000529713|||CD3E|||ENSG00000198851  ENST00000529713     CD3E
# 3     ENST00000325542|||CEP57|||ENSG00000166037  ENST00000325542    CEP57
# 4      ENST00000579456|||CLTC|||ENSG00000141367  ENST00000579456     CLTC
# 5    ENST00000554367|||DICER1|||ENSG00000100697  ENST00000554367   DICER1
# 6       ENST00000511980|||GAK|||ENSG00000178950  ENST00000511980      GAK
# 7       ENST00000252951|||HBZ|||ENSG00000130656  ENST00000252951      HBZ
# 8      ENST00000329908|||IST1|||ENSG00000182149  ENST00000329908     IST1
# 9     ENST00000650479|||ITM2B|||ENSG00000136156  ENST00000650479    ITM2B
# 10  ENST00000362698|||RNU5A-1|||ENSG00000199568  ENST00000362698  RNU5A-1
# 11   ENST00000472481|||RPL13A|||ENSG00000142541  ENST00000472481   RPL13A
# 12    ENST00000647841|||RPS17|||ENSG00000182774  ENST00000647841    RPS17
# 13    ENST00000549518|||SENP1|||ENSG00000079387  ENST00000549518    SENP1
# 14    ENST00000507126|||SRP72|||ENSG00000174780  ENST00000507126    SRP72
# 15  ENST00000483001|||TMEM234|||ENSG00000160055  ENST00000483001  TMEM234
# 16     ENST00000530271|||WNK1|||ENSG00000060237  ENST00000530271     WNK1
#
#    Ensemble_gene_ID                                               Name
# 0   ENSG00000131503  ankyrin repeat and KH domain containing 1 [Sou...
# 1   ENSG00000089820  Rho GTPase activating protein 4 [Source:HGNC S...
# 2   ENSG00000198851   CD3e molecule [Source:HGNC Symbol;Acc:HGNC:1674]
# 3   ENSG00000166037  centrosomal protein 57 [Source:HGNC Symbol;Acc...
# 4   ENSG00000141367  clathrin heavy chain [Source:HGNC Symbol;Acc:H...
# 5   ENSG00000100697  dicer 1, ribonuclease III [Source:HGNC Symbol;...
# 6   ENSG00000178950  cyclin G associated kinase [Source:HGNC Symbol...
# 7   ENSG00000130656  hemoglobin subunit zeta [Source:HGNC Symbol;Ac...
# 8   ENSG00000182149  IST1 factor associated with ESCRT-III [Source:...
# 9   ENSG00000136156  integral membrane protein 2B [Source:HGNC Symb...
# 10  ENSG00000199568  RNA, U5A small nuclear 1 [Source:HGNC Symbol;A...
# 11  ENSG00000142541  ribosomal protein L13a [Source:HGNC Symbol;Acc...
# 12  ENSG00000182774  ribosomal protein S17 [Source:HGNC Symbol;Acc:...
# 13  ENSG00000079387  SUMO specific peptidase 1 [Source:HGNC Symbol;...
# 14  ENSG00000174780  signal recognition particle 72 [Source:HGNC Sy...
# 15  ENSG00000160055  transmembrane protein 234 [Source:HGNC Symbol;...
# 16  ENSG00000060237  WNK lysine deficient protein kinase 1 [Source:...

# %%
psp_data_7=pd.read_excel(path1/"genelists_102_17_7_DEGs_genes.xlsx",sheet_name='7 genes from regression',header=None)
psp_data_7.dropna(how='all')
new_psp_7=psp_data_7.dropna(axis=1,how='all')
#new_psp_7

column =list(new_psp_7.iloc[0])

new_psp_7.columns = column

a_new_7 = new_psp_7[2:]

a_new_7.reset_index(drop=True,inplace=True)

a_new_7
